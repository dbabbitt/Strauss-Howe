# %%
import sys

# Insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '../py')

# %%
# %pprint
# %run ../load_magic/storage.py
# %run ../load_magic/paths.py
# %run ../load_magic/lists.py
# %run ../load_magic/environment.py
# %run ../load_magic/dataframes.py

import scraping_utils
wikipedia = scraping_utils.wikipedia

from bs4 import BeautifulSoup as bs
import networkx as nx
import re
import urllib.request

notebook_path = get_notebook_path()
print(notebook_path)
s = Storage()
#pandemic_df = s.load_object('pandemic_df')
print(['s.{}'.format(fn) for fn in dir(s) if not fn.startswith('_')])

dir()
# Out:
# Pretty printing has been turned OFF
# C:\ProgramData\Anaconda3\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# None
# ['s.attempt_to_pickle', 's.csv_exists', 's.data_csv_folder', 's.data_folder', 's.encoding_type', 's.load_csv', 's.load_dataframes', 's.load_object', 's.pickle_exists', 's.save_dataframes', 's.saves_csv_folder', 's.saves_folder', 's.saves_pickle_folder', 's.store_objects']
# ['Config', 'FILEPATH_REGEX', 'In', 'Out', 'Path', 'RandomForestClassifier', 'SequenceMatcher', 'Storage', 'URL_REGEX', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__nonzero__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i2', '_ih', '_ii', '_iii', '_oh', 'bs', 'check_4_doubles', 'check_for_typos', 'conjunctify_nouns', 'copyfile', 'csv', 'encoding', 'example_iterrows', 'exit', 'get_all_files_containing', 'get_classifier', 'get_column_descriptions', 'get_data_structs_dataframe', 'get_datastructure_prediction', 'get_dir_tree', 'get_git_lfs_track_commands', 'get_importances', 'get_input_sample', 'get_ipython', 'get_max_rsquared_adj', 'get_module_version', 'get_modules_dataframe', 'get_notebook_path', 'get_page_soup', 'get_page_tables', 'get_specific_gitignore_files', 'get_struct_name', 'get_wiki_tables', 'humanize_bytes', 'io', 'ipykernel', 'json', 'jupyter_config_dir', 'math', 'notebook_path', 'notebookapp', 'np', 'nx', 'os', 'pd', 'pickle', 'plt', 'preprocess_data', 'print_all_files_ending_starting_with', 'print_all_files_ending_with', 'print_all_files_starting_with', 'quit', 'random', 're', 'remove_empty_folders', 's', 'scraping_utils', 'similar', 'sm', 'sns', 'stats', 'subprocess', 'sys', 'time', 'urllib', 'urlretrieve', 'wikipedia']

# %%
tables_url = 'https://en.wikipedia.org/wiki/Historical_rankings_of_presidents_of_the_United_States'
tables_list = get_page_tables(tables_url)
# Out:
# [(0, (46, 27)), (8, (47, 24)), (6, (46, 24)), (2, (45, 24)), (7, (46, 14)), (5, (45, 14)), (3, (45, 9)), (4, (45, 9)), (11, (11, 8)), (12, (9, 7)), (1, (18, 3)), (10, (14, 3)), (13, (14, 2)), (9, (1, 5)), (14, (2, 2))]

# %%
cn_dict = {}
cn_dict['Bg'] = 'Background'
cn_dict['PL'] = 'Party_Leadership'
cn_dict['CAb'] = 'Communication_Ability'
cn_dict['RC'] = 'Relations_With_Congress'
cn_dict['CAp'] = 'Court_Appointments'
cn_dict['HE'] = 'Handling_of_Economy'
cn_dict['L'] = 'Luck'
cn_dict['AC'] = 'Ability_to_Compromise'
cn_dict['WR'] = 'Willing_to_Take_Risks'
cn_dict['EAp'] = 'Executive_Appointments'
cn_dict['OA'] = 'Overall_Ability'
cn_dict['Im'] = 'Imagination'
cn_dict['DA'] = 'Domestic_Accomplishments'
cn_dict['Int'] = 'Integrity'
cn_dict['EAb'] = 'Executive_Ability'
cn_dict['FPA'] = 'Foreign_Policy_Accomplishments'
cn_dict['LA'] = 'Leadership_Ability'
cn_dict['IQ'] = 'Intelligence'
cn_dict['AM'] = 'Avoid_Crucial_Mistakes'
cn_dict['EV'] = 'Experts_View'
cn_dict['O'] = 'Overall'
cn_dict['Seq.'] = 'Office_Rank'
cn_dict['President'] = 'President'
cn_dict['Political party'] = 'Political_Party'

# %%
sienna_expert_poll2010_df = tables_list[6].copy()
sienna_expert_poll2010_df.columns = [cn_dict[cn].lower() for cn in sienna_expert_poll2010_df.columns]
sienna_expert_poll2010_df = sienna_expert_poll2010_df.iloc[1:-1]
sienna_expert_poll2010_df = sienna_expert_poll2010_df.applymap(lambda x: str(x).split('[')[0])
for cn in sienna_expert_poll2010_df.columns:
    if cn not in ['president', 'political_party']:
        sienna_expert_poll2010_df[cn] = sienna_expert_poll2010_df[cn].map(lambda x: re.sub('[^\d]+', '', str(x)))
        sienna_expert_poll2010_df[cn] = pd.to_numeric(sienna_expert_poll2010_df[cn], errors='coerce')
sienna_expert_poll2010_df.set_index('president', inplace=True)
sienna_expert_poll2010_df.index.name = 'President'

def f(x):
    if '_' not in x:
        x = f'presidential_{x}'
    
    return x

sienna_expert_poll2010_df.columns = [f(cn) for cn in sienna_expert_poll2010_df.columns]
sienna_expert_poll2010_df.loc['Grover Cleveland', 'office_rank'] = 24
pn_dict = {'William H. Taft': 'William Howard Taft', 'Barack Obama': 'Barack H. Obama'}
sienna_expert_poll2010_df = sienna_expert_poll2010_df.rename(index=pn_dict)
s.store_objects(sienna_expert_poll2010_df=sienna_expert_poll2010_df)
sienna_expert_poll2010_df.sample(5).T
# Out:
# Pickling to C:\Users\daveb\OneDrive\Documents\GitHub\Strauss-Howe\saves\pkl\sienna_expert_poll2010_df.pkl
# President                      Rutherford B. Hayes John F. Kennedy  \
# office_rank                                     19              35
# political_party                         Republican      Democratic
# presidential_background                         36              14
# presidential_imagination                        31               5
# presidential_integrity                          32              31
# presidential_intelligence                       29              11
# presidential_luck                               23              31
# willing_to_take_risks                           37               9
# ability_to_compromise                           24               8
# executive_ability                               34              12
# leadership_ability                              33               8
# communication_ability                           30               3
# overall_ability                                 31              11
# party_leadership                                33              17
# relations_with_congress                         30              13
# court_appointments                              27              12
# handling_of_economy                             22               7
# executive_appointments                          30               6
# domestic_accomplishments                        35              15
# foreign_policy_accomplishments                  31              17
# avoid_crucial_mistakes                          28              18
# experts_view                                    29              12
# presidential_overall                            32              10
#
# President                      Chester A. Arthur James A. Garfield  \
# office_rank                                   21                20
# political_party                       Republican        Republican
# presidential_background                       42                22
# presidential_imagination                      32                26
# presidential_integrity                        37                21
# presidential_intelligence                     36                20
# presidential_luck                             17                41
# willing_to_take_risks                         35                32
# ability_to_compromise                         22                26
# executive_ability                             30                25
# leadership_ability                            34                24
# communication_ability                         36                23
# overall_ability                               35                24
# party_leadership                              34                27
# relations_with_congress                       33                26
# court_appointments                            33                34
# handling_of_economy                           30                29
# executive_appointments                        31                27
# domestic_accomplishments                      25                34
# foreign_policy_accomplishments                32                34
# avoid_crucial_mistakes                        23                27
# experts_view                                  31                25
# presidential_overall                          34                28
#
# President                      Martin Van Buren
# office_rank                                   8
# political_party                      Democratic
# presidential_background                      24
# presidential_imagination                     23
# presidential_integrity                       27
# presidential_intelligence                    25
# presidential_luck                            34
# willing_to_take_risks                        30
# ability_to_compromise                        20
# executive_ability                            28
# leadership_ability                           27
# communication_ability                        25
# overall_ability                              27
# party_leadership                             16
# relations_with_congress                      23
# court_appointments                           25
# handling_of_economy                          31
# executive_appointments                       26
# domestic_accomplishments                     29
# foreign_policy_accomplishments               27
# avoid_crucial_mistakes                       24
# experts_view                                 28
# presidential_overall                         25

# %%
us_presidents_df = s.load_object('us_presidents_df')
pn_dict = {'William H. Taft': 'William Howard Taft', 'Barack Obama': 'Barack H. Obama'}
us_presidents_df = us_presidents_df.rename(index=pn_dict)
s.store_objects(us_presidents_df=us_presidents_df)
us_presidents_df.sample(5).T
# Out:
# Pickling to C:\Users\daveb\OneDrive\Documents\GitHub\Strauss-Howe\saves\pkl\us_presidents_df.pkl
# President                    Ulysses S. Grant          Warren G. Harding  \
# date_of_birth             1822-04-27 00:00:00        1865-11-02 00:00:00
# birthplace                     Point Pleasant             Blooming Grove
# state_of_birth                           Ohio                       Ohio
# office_rank                                18                         29
# reign_begin               1869-03-04 00:00:00        1921-03-04 00:00:00
# reign_end                 1877-03-04 00:00:00        1923-08-02 00:00:00
# turning_name      Reconstruction & Gilded Age  World War I & Prohibition
# turning_number                              1                          3
# year_of_birth                            1822                       1865
# year_reign_begin                         1869                       1921
# year_reign_end                         1877.0                     1923.0
#
# President                       Millard Fillmore         Theodore Roosevelt  \
# date_of_birth                1800-01-07 00:00:00        1858-10-27 00:00:00
# birthplace                            Summerhill                  Manhattan
# state_of_birth                          New York                   New York
# office_rank                                   13                         26
# reign_begin                  1850-07-09 00:00:00        1901-09-14 00:00:00
# reign_end                    1853-03-04 00:00:00        1909-03-04 00:00:00
# turning_name      The Mexican War & Sectionalism  The Third Great Awakening
# turning_number                                 3                          2
# year_of_birth                               1800                       1858
# year_reign_begin                            1850                       1901
# year_reign_end                            1853.0                     1909.0
#
# President                              Herbert Hoover
# date_of_birth                     1874-08-10 00:00:00
# birthplace                                West Branch
# state_of_birth                                   Iowa
# office_rank                                        31
# reign_begin                       1929-03-04 00:00:00
# reign_end                         1933-03-04 00:00:00
# turning_name      The Great Depression & World War II
# turning_number                                      4
# year_of_birth                                    1874
# year_reign_begin                                 1929
# year_reign_end                                 1933.0

# %%
us_presidents_df = s.load_object('us_presidents_df')
set(us_presidents_df.index).symmetric_difference(set(sienna_expert_poll2010_df.index))
# Out:
# {'Joseph R. Biden'}

# %%
us_presidents_df = s.load_object('us_presidents_df')
us_presidents_df = us_presidents_df.merge(sienna_expert_poll2010_df, left_index=True, right_index=True, how='left')
[f'us_presidents_df.{fn}' for fn in dir(us_presidents_df) if 'dup' in fn.lower()]
# Out:
# ['us_presidents_df._check_inplace_and_allows_duplicate_labels', 'us_presidents_df.drop_duplicates', 'us_presidents_df.duplicated']

# %%
us_presidents_df.duplicated(subset=['office_rank_x', 'office_rank_y']).any()
# Out:
# False

# %%
us_presidents_df = us_presidents_df.drop(columns=['office_rank_y']).rename(columns={'office_rank_x': 'office_rank'})

# %%
mask_series = (us_presidents_df.index == 'Joseph R. Biden')
us_presidents_df.loc[mask_series, 'political_party'] = 'Democratic'

# %%
s.store_objects(us_presidents_df=us_presidents_df)
us_presidents_df.tail(5).T
# Out:
# Pickling to C:\Users\daveb\OneDrive\Documents\GitHub\Strauss-Howe\saves\pkl\us_presidents_df.pkl
# President                                   Joseph R. Biden  \
# date_of_birth                           1942-11-20 00:00:00
# birthplace                                         Scranton
# state_of_birth                                 Pennsylvania
# office_rank                                              46
# reign_begin                             2021-01-20 00:00:00
# reign_end                                               NaT
# turning_name                    The Global Financial Crisis
# turning_number                                            4
# year_of_birth                                          1942
# year_reign_begin                                       2021
# year_reign_end                                          NaN
# political_party                                  Democratic
# presidential_background                                 NaN
# presidential_imagination                                NaN
# presidential_integrity                                  NaN
# presidential_intelligence                               NaN
# presidential_luck                                       NaN
# willing_to_take_risks                                   NaN
# ability_to_compromise                                   NaN
# executive_ability                                       NaN
# leadership_ability                                      NaN
# communication_ability                                   NaN
# overall_ability                                         NaN
# party_leadership                                        NaN
# relations_with_congress                                 NaN
# court_appointments                                      NaN
# handling_of_economy                                     NaN
# executive_appointments                                  NaN
# domestic_accomplishments                                NaN
# foreign_policy_accomplishments                          NaN
# avoid_crucial_mistakes                                  NaN
# experts_view                                            NaN
# presidential_overall                                    NaN
#
# President                                      Donald Trump  \
# date_of_birth                           1946-06-14 00:00:00
# birthplace                                           Queens
# state_of_birth                                     New York
# office_rank                                              45
# reign_begin                             2017-01-20 00:00:00
# reign_end                               2021-01-20 00:00:00
# turning_name                    The Global Financial Crisis
# turning_number                                            4
# year_of_birth                                          1946
# year_reign_begin                                       2017
# year_reign_end                                       2021.0
# political_party                                  Republican
# presidential_background                                44.0
# presidential_imagination                               41.0
# presidential_integrity                                 44.0
# presidential_intelligence                              44.0
# presidential_luck                                      10.0
# willing_to_take_risks                                  25.0
# ability_to_compromise                                  43.0
# executive_ability                                      42.0
# leadership_ability                                     42.0
# communication_ability                                  43.0
# overall_ability                                        44.0
# party_leadership                                       43.0
# relations_with_congress                                43.0
# court_appointments                                     40.0
# handling_of_economy                                    39.0
# executive_appointments                                 44.0
# domestic_accomplishments                               40.0
# foreign_policy_accomplishments                         42.0
# avoid_crucial_mistakes                                 41.0
# experts_view                                           42.0
# presidential_overall                                   42.0
#
# President                                     George W. Bush  \
# date_of_birth                            1946-07-06 00:00:00
# birthplace                                         New Haven
# state_of_birth                                   Connecticut
# office_rank                                               43
# reign_begin                              2001-01-20 00:00:00
# reign_end                                2009-01-20 00:00:00
# turning_name                    The Long Boom & Culture Wars
# turning_number                                             3
# year_of_birth                                           1946
# year_reign_begin                                        2001
# year_reign_end                                        2009.0
# political_party                                   Republican
# presidential_background                                 17.0
# presidential_imagination                                30.0
# presidential_integrity                                  33.0
# presidential_intelligence                               41.0
# presidential_luck                                       21.0
# willing_to_take_risks                                   20.0
# ability_to_compromise                                   29.0
# executive_ability                                       35.0
# leadership_ability                                      31.0
# communication_ability                                   38.0
# overall_ability                                         38.0
# party_leadership                                        19.0
# relations_with_congress                                 22.0
# court_appointments                                      28.0
# handling_of_economy                                     36.0
# executive_appointments                                  29.0
# domestic_accomplishments                                30.0
# foreign_policy_accomplishments                          38.0
# avoid_crucial_mistakes                                  36.0
# experts_view                                            34.0
# presidential_overall                                    33.0
#
# President                                       Bill Clinton  \
# date_of_birth                            1946-08-19 00:00:00
# birthplace                                              Hope
# state_of_birth                                      Arkansas
# office_rank                                               42
# reign_begin                              1993-01-20 00:00:00
# reign_end                                2001-01-20 00:00:00
# turning_name                    The Long Boom & Culture Wars
# turning_number                                             3
# year_of_birth                                           1946
# year_reign_begin                                        1993
# year_reign_end                                        2001.0
# political_party                                   Democratic
# presidential_background                                 21.0
# presidential_imagination                                13.0
# presidential_integrity                                  39.0
# presidential_intelligence                                8.0
# presidential_luck                                       11.0
# willing_to_take_risks                                   17.0
# ability_to_compromise                                    3.0
# executive_ability                                       16.0
# leadership_ability                                      15.0
# communication_ability                                    8.0
# overall_ability                                         13.0
# party_leadership                                        13.0
# relations_with_congress                                 18.0
# court_appointments                                      10.0
# handling_of_economy                                      5.0
# executive_appointments                                  12.0
# domestic_accomplishments                                 9.0
# foreign_policy_accomplishments                          18.0
# avoid_crucial_mistakes                                  30.0
# experts_view                                            14.0
# presidential_overall                                    15.0
#
# President                                   Barack H. Obama
# date_of_birth                           1961-08-04 00:00:00
# birthplace                                         Honolulu
# state_of_birth                                       Hawaii
# office_rank                                              44
# reign_begin                             2009-01-20 00:00:00
# reign_end                               2017-01-20 00:00:00
# turning_name                    The Global Financial Crisis
# turning_number                                            4
# year_of_birth                                          1961
# year_reign_begin                                       2009
# year_reign_end                                       2017.0
# political_party                                  Democratic
# presidential_background                                25.0
# presidential_imagination                               11.0
# presidential_integrity                                 13.0
# presidential_intelligence                               9.0
# presidential_luck                                      15.0
# willing_to_take_risks                                  23.0
# ability_to_compromise                                  16.0
# executive_ability                                      18.0
# leadership_ability                                     16.0
# communication_ability                                   9.0
# overall_ability                                        15.0
# party_leadership                                       23.0
# relations_with_congress                                31.0
# court_appointments                                     14.0
# handling_of_economy                                    10.0
# executive_appointments                                 13.0
# domestic_accomplishments                               13.0
# foreign_policy_accomplishments                         20.0
# avoid_crucial_mistakes                                 10.0
# experts_view                                           11.0
# presidential_overall                                   17.0

# %%
[f'us_presidents_df.{fn}' for fn in dir(us_presidents_df) if 'cor' in fn.lower()]
# Out:
# ['us_presidents_df.corr', 'us_presidents_df.corrwith', 'us_presidents_df.from_records', 'us_presidents_df.to_records']

# %%
generations_df = s.load_object('generations_df')
for cn in ['birth_year_begin', 'birth_year_end', 'turning_year_begin', 'turning_year_end']:
    cn_dict = generations_df[cn].to_dict()
    us_presidents_df[cn] = us_presidents_df.generation_name.map(lambda x: cn_dict[x])

# %%
us_presidents_df.columns.tolist()
# Out:
# ['date_of_birth', 'birthplace', 'state_of_birth', 'office_rank', 'reign_begin', 'reign_end', 'generation_name', 'turning_name', 'turning_number', 'political_party', 'presidential_background', 'presidential_imagination', 'presidential_integrity', 'presidential_intelligence', 'presidential_luck', 'willing_to_take_risks', 'ability_to_compromise', 'executive_ability', 'leadership_ability', 'communication_ability', 'overall_ability', 'party_leadership', 'relations_with_congress', 'court_appointments', 'handling_of_economy', 'executive_appointments', 'domestic_accomplishments', 'foreign_policy_accomplishments', 'avoid_crucial_mistakes', 'experts_view', 'presidential_overall', 'birth_year_begin', 'birth_year_end', 'turning_year_begin', 'turning_year_end']

# %%
import numpy as np

max_corr = 0
max_row = np.nan
max_col = np.nan
us_presidents_df['office_rank'] = pd.to_numeric(us_presidents_df['office_rank'], errors='coerce')
corr_df = us_presidents_df.corr()
old_columns = ['office_rank', 'turning_number', 'birth_year_begin', 'birth_year_end', 'turning_year_begin',
               'turning_year_end']
new_columns = ['presidential_background', 'presidential_imagination', 'presidential_integrity',
               'presidential_intelligence', 'presidential_luck', 'willing_to_take_risks', 'ability_to_compromise',
               'executive_ability', 'leadership_ability', 'communication_ability', 'overall_ability', 'party_leadership',
               'relations_with_congress', 'court_appointments', 'handling_of_economy', 'executive_appointments',
               'domestic_accomplishments', 'foreign_policy_accomplishments', 'avoid_crucial_mistakes', 'experts_view',
               'presidential_overall']
mask_series = corr_df.index.isin(new_columns)
for row_index, row_series in corr_df[mask_series].iterrows():
    for col_index, col_value in row_series.iteritems():
        if (col_index in old_columns) and (col_value < 1.0) and (col_value > max_corr):
            max_corr = col_value
            max_row = row_index
            max_col = col_index
print("us_presidents_df.plot.scatter(x='{}', y='{}');".format(max_row, max_col))
# Out:
# us_presidents_df.plot.scatter(x='presidential_integrity', y='birth_year_end');

# %%
import numpy as np

max_corr = 0
max_row = np.nan
max_col = np.nan
us_presidents_df['office_rank'] = pd.to_numeric(us_presidents_df['office_rank'], errors='coerce')
corr_df = us_presidents_df.corr()
old_columns = ['presidential_integrity']
new_columns = ['presidential_background', 'presidential_imagination',
               'presidential_intelligence', 'presidential_luck', 'willing_to_take_risks', 'ability_to_compromise',
               'executive_ability', 'leadership_ability', 'communication_ability', 'overall_ability', 'party_leadership',
               'relations_with_congress', 'court_appointments', 'handling_of_economy', 'executive_appointments',
               'domestic_accomplishments', 'foreign_policy_accomplishments', 'avoid_crucial_mistakes', 'experts_view',
               'presidential_overall']
mask_series = corr_df.index.isin(new_columns)
for row_index, row_series in corr_df[mask_series].iterrows():
    for col_index, col_value in row_series.iteritems():
        if (col_index in old_columns) and (col_value < 1.0) and (col_value > max_corr):
            max_corr = col_value
            max_row = row_index
            max_col = col_index
print("us_presidents_df.plot.scatter(x='{}', y='{}');".format(max_row, max_col))
# Out:
# us_presidents_df.plot.scatter(x='avoid_crucial_mistakes', y='presidential_integrity');

# %%
# %matplotlib inline
save_fig_as_various(us_presidents_df, 'Wile E. Coyote Syndrone: Avoiding Crucial Mistakes by having Integrity')
# Out:
# 'DataFrame' object has no attribute 'savefig'
# 'DataFrame' object has no attribute 'savefig'
# 'DataFrame' object has no attribute 'savefig'

# %%
[fn for fn in dir() if 'save' in fn.lower()]
# Out:
# ['save_fig_as_various']

# %%
columns_list = ['office_rank', 'generation_name', 'turning_name', 'turning_number', 'political_party',
                'presidential_integrity', 'avoid_crucial_mistakes', 'experts_view', 'presidential_overall',
                'birth_year_begin', 'birth_year_end', 'turning_year_begin', 'turning_year_end']
us_presidents_df[columns_list].sort_values('presidential_integrity').tail(5).T
# Out:
# President                               James Buchanan  \
# office_rank                                         15
# generation_name                             Compromise
# turning_name            The Mexican War & Sectionalism
# turning_number                                       3
# political_party                             Democratic
# presidential_integrity                              40
# avoid_crucial_mistakes                              44
# experts_view                                        44
# presidential_overall                                43
# birth_year_begin                                  1767
# birth_year_end                                    1791
# turning_year_begin                                1773
# turning_year_end                                  1794
#
# President                            Andrew Johnson  \
# office_rank                                      17
# generation_name                      Transcendental
# turning_name            Reconstruction & Gilded Age
# turning_number                                    1
# political_party                          Democratic
# presidential_integrity                           41
# avoid_crucial_mistakes                           43
# experts_view                                     43
# presidential_overall                             44
# birth_year_begin                               1792
# birth_year_end                                 1821
# turning_year_begin                             1794
# turning_year_end                               1822
#
# President                       Warren G. Harding  \
# office_rank                                    29
# generation_name                        Missionary
# turning_name            World War I & Prohibition
# turning_number                                  3
# political_party                        Republican
# presidential_integrity                         42
# avoid_crucial_mistakes                         39
# experts_view                                   41
# presidential_overall                           41
# birth_year_begin                             1860
# birth_year_end                               1882
# turning_year_begin                           1865
# turning_year_end                             1886
#
# President                              Richard Nixon  \
# office_rank                                       37
# generation_name                                 G.I.
# turning_name            The Consciousness Revolution
# turning_number                                     2
# political_party                           Republican
# presidential_integrity                            43
# avoid_crucial_mistakes                            42
# experts_view                                      38
# presidential_overall                              29
# birth_year_begin                                1901
# birth_year_end                                  1924
# turning_year_begin                              1908
# turning_year_end                                1929
#
# President                              Donald Trump
# office_rank                                      45
# generation_name                           Baby Boom
# turning_name            The Global Financial Crisis
# turning_number                                    4
# political_party                          Republican
# presidential_integrity                           44
# avoid_crucial_mistakes                           41
# experts_view                                     42
# presidential_overall                             42
# birth_year_begin                               1943
# birth_year_end                                 1960
# turning_year_begin                             1946
# turning_year_end                               1963

# %%
columns_list = ['office_rank', 'generation_name', 'turning_name', 'turning_number', 'political_party',
                'presidential_integrity', 'avoid_crucial_mistakes', 'experts_view', 'presidential_overall',
                'birth_year_begin', 'birth_year_end', 'turning_year_begin', 'turning_year_end']
us_presidents_df[columns_list].sort_values('avoid_crucial_mistakes').tail(5).T
# Out:
# President                                    Herbert Hoover  \
# office_rank                                              31
# generation_name                                  Missionary
# turning_name            The Great Depression & World War II
# turning_number                                            4
# political_party                                  Republican
# presidential_integrity                                   15
# avoid_crucial_mistakes                                   40
# experts_view                                             35
# presidential_overall                                     36
# birth_year_begin                                       1860
# birth_year_end                                         1882
# turning_year_begin                                     1865
# turning_year_end                                       1886
#
# President                              Donald Trump  \
# office_rank                                      45
# generation_name                           Baby Boom
# turning_name            The Global Financial Crisis
# turning_number                                    4
# political_party                          Republican
# presidential_integrity                           44
# avoid_crucial_mistakes                           41
# experts_view                                     42
# presidential_overall                             42
# birth_year_begin                               1943
# birth_year_end                                 1960
# turning_year_begin                             1946
# turning_year_end                               1963
#
# President                              Richard Nixon  \
# office_rank                                       37
# generation_name                                 G.I.
# turning_name            The Consciousness Revolution
# turning_number                                     2
# political_party                           Republican
# presidential_integrity                            43
# avoid_crucial_mistakes                            42
# experts_view                                      38
# presidential_overall                              29
# birth_year_begin                                1901
# birth_year_end                                  1924
# turning_year_begin                              1908
# turning_year_end                                1929
#
# President                            Andrew Johnson  \
# office_rank                                      17
# generation_name                      Transcendental
# turning_name            Reconstruction & Gilded Age
# turning_number                                    1
# political_party                          Democratic
# presidential_integrity                           41
# avoid_crucial_mistakes                           43
# experts_view                                     43
# presidential_overall                             44
# birth_year_begin                               1792
# birth_year_end                                 1821
# turning_year_begin                             1794
# turning_year_end                               1822
#
# President                               James Buchanan
# office_rank                                         15
# generation_name                             Compromise
# turning_name            The Mexican War & Sectionalism
# turning_number                                       3
# political_party                             Democratic
# presidential_integrity                              40
# avoid_crucial_mistakes                              44
# experts_view                                        44
# presidential_overall                                43
# birth_year_begin                                  1767
# birth_year_end                                    1791
# turning_year_begin                                1773
# turning_year_end                                  1794

# %%
get_column_descriptions(us_presidents_df)
# Out:
#                        column_name           dtype  count_blanks  \
# 0                    date_of_birth  datetime64[ns]             0
# 1                      reign_begin  datetime64[ns]             0
# 2                        reign_end  datetime64[ns]             1
# 3                   turning_number           int64             0
# 4          presidential_background           int64             0
# 5         presidential_imagination           int64             0
# 6           presidential_integrity           int64             0
# 7        presidential_intelligence           int64             0
# 8                presidential_luck           int64             0
# 9            willing_to_take_risks           int64             0
# 10           ability_to_compromise           int64             0
# 11               executive_ability           int64             0
# 12              leadership_ability           int64             0
# 13           communication_ability           int64             0
# 14                 overall_ability           int64             0
# 15                party_leadership           int64             0
# 16         relations_with_congress           int64             0
# 17              court_appointments           int64             0
# 18             handling_of_economy           int64             0
# 19          executive_appointments           int64             0
# 20        domestic_accomplishments           int64             0
# 21  foreign_policy_accomplishments           int64             0
# 22          avoid_crucial_mistakes           int64             0
# 23                    experts_view           int64             0
# 24            presidential_overall           int64             0
# 25                birth_year_begin           int64             0
# 26              turning_year_begin           int64             0
# 27                  birth_year_end         float64             0
# 28                turning_year_end         float64             0
# 29                      birthplace          object             0
# 30                  state_of_birth          object             0
# 31                     office_rank          object             0
# 32                 generation_name          object             0
# 33                    turning_name          object             0
# 34                 political_party          object             0
#
#     count_uniques  count_zeroes  has_dates            min_value  \
# 0              44             0       True  1732-02-22 00:00:00
# 1              45             0       True  1789-04-30 00:00:00
# 2              45             0       True  1797-03-04 00:00:00
# 3               4             0       True                    1
# 4              43             0       True                    1
# 5              43             0       True                    1
# 6              44             0       True                    1
# 7              44             0       True                    1
# 8              44             0       True                    1
# 9              41             0       True                    1
# 10             43             0       True                    1
# 11             43             0       True                    1
# 12             44             0       True                    1
# 13             44             0       True                    1
# 14             44             0       True                    1
# 15             44             0       True                    1
# 16             43             0       True                    1
# 17             44             0       True                    1
# 18             44             0       True                    1
# 19             44             0       True                    1
# 20             44             0       True                    1
# 21             44             0       True                    1
# 22             44             0       True                    1
# 23             44             0       True                    1
# 24             44             0       True                    1
# 25             11             0       True                 1724
# 26             11             0       True                 1727
# 27             11             0       True                 1741
# 28             11             0       True                 1746
# 29             42             0      False        Barboursville
# 30             20             0      False             Arkansas
# 31             45             0      False                    1
# 32             11             0      False                 13th
# 33             13             0      False  American Revolution
# 34              6             0      False           Democratic
#
#                     max_value only_integers
# 0         1961-08-04 00:00:00           NaN
# 1         2017-01-20 00:00:00           NaN
# 2         2017-01-20 00:00:00           NaN
# 3                           4          True
# 4                          43          True
# 5                          43          True
# 6                          44          True
# 7                          44          True
# 8                          44          True
# 9                          41          True
# 10                         43          True
# 11                         43          True
# 12                         44          True
# 13                         44          True
# 14                         44          True
# 15                         44          True
# 16                         43          True
# 17                         44          True
# 18                         44          True
# 19                         44          True
# 20                         44          True
# 21                         44          True
# 22                         44          True
# 23                         44          True
# 24                         44          True
# 25                       1961          True
# 26                       1963          True
# 27                       1981          True
# 28                       1983          True
# 29                Yorba Linda           NaN
# 30                   Virginia           NaN
# 31                          9          True
# 32             Transcendental           NaN
# 33  World War I & Prohibition           NaN
# 34                       Whig           NaN
